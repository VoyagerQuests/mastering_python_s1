# %% [markdown]
# No Type Hints

# %%
def say_hi(name):
    return f"Hey {name.strip().title()}!"

# %% [markdown]
# With Comments

# %%
def say_hi(name):
    """
    Input: name: str (no other type supported)
    Output: str
    """
    return f"Hey {name.strip().title()}!"

# %%
print(say_hi("  arion silvaris "))
# Out:
# Hey Arion Silvaris!

# %%
print(say_hi(["  arion silvaris "]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(say_hi(["  arion silvaris "]))
#
# Cell In[1], line 6, in say_hi(name)
#       1 def say_hi(name):
#       2     """
#       3     Input: name: str (no other type supported)
#       4     Output: str
#       5     """
# ----> 6     return f"Hey {name.strip().title()}!"
#
# AttributeError: 'list' object has no attribute 'strip'

# %% [markdown]
# With types

# %%
def say_hi(name: str) -> str:
    return f"Hey {name}!"

# %%
print(say_hi(["  arion silvaris "]))
# Out:
# Hey ['  arion silvaris ']!

# %% [markdown]
# A more complicated example

# %%
def total_character_count(words):
    total = 0
    for char in words:
        total += len(char)
    return total

# %%
print(total_character_count(["Hello", " world!"]))
# Out:
# 12

# %%
print(total_character_count(12345))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(total_character_count(12345))
#
# Cell In[6], line 3, in total_character_count(words)
#       1 def total_character_count(words):
#       2     total = 0
# ----> 3     for char in words:
#       4         total += len(char)
#       5     return total
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# Now with type hints

# %%
def total_character_count(words: list[str]) -> int:
    total = 0
    for char in words:
        total += len(char)
    return total

print(total_character_count(["Hello", " world!"]))
print(total_character_count(12345))
# Out:
# 12
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 8
#       5     return total
#       7 print(total_character_count(["Hello", " world!"]))
# ----> 8 print(total_character_count(12345))
#
# Cell In[9], line 3, in total_character_count(words)
#       1 def total_character_count(words: list[str]) -> int:
#       2     total = 0
# ----> 3     for char in words:
#       4         total += len(char)
#       5     return total
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# Make it more flexible

# %%
from collections.abc import Iterable

def total_character_count(words: Iterable[str]) -> int:
    total = 0
    for char in words:
        total += len(char)
    return total

print(total_character_count(["Hello", " world!"]))               # list of strings
print(total_character_count(("Hello", " world!")))               # tuple of strings
print(total_character_count({"Hello", " world!"}))               # set of strings
print(total_character_count(word for word in ["Hello", " world!"])) # generator yielding strings
print(total_character_count(iter(["Hello", " world!"])))         # iterator of strings
print(total_character_count("Hello world!"))  
print(total_character_count(12345))
# Out:
# 12
# 12
# 12
# 12
# 12
# 12
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 15
#      13 print(total_character_count(iter(["Hello", " world!"])))         # iterator of strings
#      14 print(total_character_count("Hello world!"))
# ---> 15 print(total_character_count(12345))
#
# Cell In[10], line 5, in total_character_count(words)
#       3 def total_character_count(words: Iterable[str]) -> int:
#       4     total = 0
# ----> 5     for char in words:
#       6         total += len(char)
#       7     return total
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# ---
