# %% [markdown]
# ### Figure out how you should use this function...

# %%
def update_attribute(character, attribute_name, delta):

    if attribute_name not in character["attributes"]:
        raise ValueError("Unknown attribute")

    character["attributes"][attribute_name] += delta

    return character

# %% [markdown]
# ### Comments will make understanding what is going on easier.

# %%
def update_attribute(character, attribute_name, delta):
    """
    Update a character's attribute by adding a delta value.

    character: a dictionary representing the character.
        Expected structure:
        {
            "name": str,
            "attributes": {
                "Might": int,
                "Agility": int,
                "Vitality": int,
                ...
            }
        }

    attribute_name: the name of the attribute to update (string)
    delta: the amount to add or subtract (integer)

    Returns the updated character dictionary.
    """

    if attribute_name not in character["attributes"]:
        raise ValueError("Unknown attribute")

    character["attributes"][attribute_name] += delta

    return character

# %% [markdown]
# ### Create character incorrect attributes
# - "attributes" misspelled as attribute
# - "Agility" capitalization issue as "Agilety"
# - "Might" is capitalized as "might"

# %%
character = {
    "name": "Aelar",
    "attribute": {
        "might": 10,
        "Agilety": 8,
    },
}

print(character)

# %% [markdown]
# ### This function call is 100% correct according to the spec
# - Data corruption will lead to unexpected down-the-road issues

# %%
update_attribute(character, "Might", 2)
